# %% [markdown]
# <a href="https://colab.research.google.com/github/murali-marimekala/pg-genai-ml/blob/main/Wk2_Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Modules
#
# ## Buildin modules
# - Math Module
# - Datetime module
#
#
#
# ##Custom Modules

# %%
# Importing math module
import math
help(math.ceil)
print(math.ceil(9.45))
# Out:
# Help on built-in function ceil in module math:
#
# ceil(x, /)
#     Return the ceiling of x as an Integral.
#
#     This is the smallest integer >= x.
#
# 10

# %%
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
res = math.gcd(n1,n2)
print(res)
# Out:
# Enter first number: 3
# Enter second number: 6
# 3

# %%
# Datetime module
import datetime as d
now = d.datetime.now()

print(now)
# Out:
# 2026-02-15 14:41:44.379181

# %%
help(d.datetime)
# Out:
# Help on class datetime in module datetime:
#
# class datetime(date)
#  |  datetime(year, month, day[, hour[, minute[, second[, microsecond[,tzinfo]]]]])
#  |
#  |  The year, month and day arguments are required. tzinfo may be None, or an
#  |  instance of a tzinfo subclass. The remaining arguments may be ints.
#  |
#  |  Method resolution order:
#  |      datetime
#  |      date
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
# ...

# %%
# List of all functions present in math module
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']
