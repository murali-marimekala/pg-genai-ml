# %% [markdown]
# <a href="https://colab.research.google.com/github/murali-marimekala/pg-genai-ml/blob/main/Python_refresh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!!")
# Out:
# Hello World!!

# %%
import sys
print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:11:29) [Clang 20.1.8 ]

# %% [markdown]
# # Variables

# %%
# Variables in Python is created when you asisgn a value to it. Python is a dynamically typed language, which means you don't need to declare the type of variable explicitly.
x = 5
y = "John"

print(x)
print(y)
# Out:
# 5
# John

# %%
# You can change the value of a variable, and it can even change its type.
x = 10
x = "Hello"
print(x)
# Out:
# Hello

# %%
# Casting in Python is the process of converting a variable from one type to another.
# You can use built-in functions like str(), int(), and float() to perform casting.
x = str(3)    # x will be '3
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
# Type() function is used to determine the type of a variable.
x = 5
y = 10.5
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
#Single and double quotes can be used to create string literals in Python.
# Both are functionally equivalent, and you can use either based on your preference or to avoid the need for escaping characters.
str = "Hello World"
print(str)

str2 = 'Hello World'
print(str2)
# Out:
# Hello World
# Hello World

# %%
# a will not overwrite A
a=10
A="Rana"
print(A)
# Out:
# Rana

# %% [markdown]
# # Variable names

# %%
# Variable names are case-sensitive in Python. This means that a variable named "a" is different from a variable named "A".

var1 = 10
var_1 = 20
_var_1 = 30
VAR1=40
print(var1)
print(var_1)
print(_var_1)
print(VAR1)
# Out:
# 10
# 20
# 30
# 40

# %%
# Invalid variable names
var-1 = 50
var 1 = 60
1var=70
# Out:
#   Cell In[17], line 3
#     1var=70
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # Multi Words Variable Names

# %%
#Camel case
myVariableName = "Rana"

#Pascal case
MyVariableName = "Rana"

#Snake case
my_variable_name = "Rana"

print(myVariableName)
print(MyVariableName)
print(my_variable_name)
# Out:
# Rana
# Rana
# Rana

# %% [markdown]
# # Many Values to Multiple Variables

# %%
# One value to multiple variables
x, y, z = "Orange", 5,  6.8
print(x)
print(y)
print(z)
# Out:
# Orange
# 5
# 6.8

# %% [markdown]
# # One Value to Multiple Variables

# %%
# One value to multiple variables
x=y=z=10
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %% [markdown]
# # Unpack a Collection

# %%
# Unpacking a collection
fruits = ["Banana", "Strawberry", "Craneberry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# Banana
# Strawberry
# Craneberry

# %% [markdown]
# # Output Variabels

# %%
# Print function is often used to ouptut variables
x = "Python is awsome"
print(x)
# Out:
# Python is awsome

# %%
# Print has its limitations. If you combine a string and a number with the + opeartor , python will give you an error
x = 5
y = "Rana"
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3705018401.py in <cell line: 0>()
#       2 x = 5
#       3 y = "Rana"
# ----> 4 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # Global Variable

# %%
#Variables that are created outside a function are known as global variables

x = "awesome"

def myfun():
  print("Python is " + x)

myfun()
# Out:
# Python is awesome

# %%
# If you create a variable with the same name inside a function , this variable wilil be local and can be only used inside the fucntion.

x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x) # Displays fantastic the local variable value

myfunc()

print("Python is " + x) # Displays awesome the global variable value
# Out:
# Python is fantastic
# Python is awesome

# %% [markdown]
# # The Global Keyword

# %%
# If you use global keyword, the variable belogs to the global scope

def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is "+x)
# Out:
# Python is fantastic

# %%
# Use global keyword if you want ot change a global vairable inside a function

x = "awesome"

def myfunc():
  global x
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x) # global value of x "awesome" is overwritten by "fantastic"
# Out:
# Python is fantastic
# Python is fantastic

# %% [markdown]
# # Python Data Type
#
# - Text type : str
# - Numeric types :  int, float, complex
# - Sequence Types : list, tuple, range
# - Mapping Type : dict
# - Set Types : set, frozenset
# - Boolean Type : bool
# - Binary Types : bytes, bytearray, memoryview
# - None Type : NoneType

# %% [markdown]
# #Getting the Data type

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# # Setting the data type

# %%
x = "Hello world"
print(type(x))

x = 20
print(type(x))

x = 20.5
print(type(x))

x = 1j
print(type(x))

x = ["apple", "banana", "cherry"]
print(type(x))

x = ("apple", "banana", "cherry")
print(type(x))

x = range(6)
print(type(x))

x = {"name" : "John", "age" : 36}
print(type(x))

x=frozenset({"apple", "banana", "cherry"})
print(type(x))

x = {"apple", "banana", "cherry"}
print(type(x))

x = True
print(type(x))

x = memoryview(bytes(5))
print(type(x))

x=b"hello"
print(type(x))

x=bytearray(5)
print(type(x))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'list'>
# <class 'tuple'>
# <class 'range'>
# <class 'dict'>
# <class 'frozenset'>
# <class 'set'>
# <class 'bool'>
# <class 'memoryview'>
# <class 'bytes'>
# <class 'bytearray'>

# %% [markdown]
# # Setting the specific Data Type

# %%
x = str("Hello world")
print(type(x))

x = int(20)
print(type(x))

x = float(20.5)
print(type(x))

x = complex(1j)
print(type(x))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>
