# %% [markdown]
# <a href="https://colab.research.google.com/github/murali-marimekala/pg-genai-ml/blob/main/Python_Programming/sessions/wk2-day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # List Comprehension

# %%
fruits = ["apple","banana","cherry"]
lst = []
for x in fruits:
  if "a" in x:
    lst.append(x)
print(lst)
# Out:
# ['apple', 'banana']

# %%
[x for x in fruits if "a" in x]
# Out:
# ['apple', 'banana']

# %%
# Syntax of list compehension

# newlist. [expression for item in iterable if condition == True]

# %%
# Get list of even number greater than 4 from list
lst = [1,2,4,3,4,5,63,8,16]
a=[]
for x in lst:
  if x%2==0 and x >4:
    a.append(x)
print(a)
# Out:
# [8, 16]

# %%
# Getting above result using List Comprehension
lst = [34,2,4,5,7,7,8,16]
[x for x in lst if x%2 ==0 and x>4 ]

a1 = [x if x%2 == 0 and x > 4 for x in lst]
# Out:
#   File "/tmp/ipython-input-4062205634.py", line 5
#     a1 = [x if x%2 == 0 and x > 4 for x in lst]
#           ^
# SyntaxError: expected 'else' after 'if' expression
